# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('zolo-sample-data.csv')

# %%
df.head()
# Out:
#                                          fields_data  sf_last_modified_at  \
# 0  {"AnnualRevenue": "", "City": "", "Company": "...           1597054409
# 1  {"AnnualRevenue": "", "City": "", "Company": "...           1597126433
# 2  {"AnnualRevenue": "", "City": "", "Company": "...           1597127006
# 3  {"AnnualRevenue": "", "City": "", "Company": "...           1597228892
# 4  {"AnnualRevenue": "", "City": "", "Company": "...           1597299110
#
#    sf_created_at    website_text  created_at              zolo_lead_id  \
# 0     1597053456     offerup.com  1597056317  5db811f786a45530631d9755
# 1     1597126037     offerup.com  1597126522  5ebb8d820d43c85284262956
# 2     1597125832  u-clermont1.fr  1597128317  5e4cf8155d8c6b1d2f97f5f5
# 3     1597228366       metso.com  1597229117                       NaN
# 4     1597298014      oracle.com  1597301117  5db918a66f7c02b4fc11dc76
#
#   sf_lead_company_website    sf_lead_company_name          sf_lead_id  \
# ...

# %%
df['sf_last_modified_at']
# Out:
# 0       1597054409
# 1       1597126433
# 2       1597127006
# 3       1597228892
# 4       1597299110
#            ...
# 9995    1593528696
# 9996    1593528710
# 9997    1593528715
# 9998    1593528700
# 9999    1597394514
# Name: sf_last_modified_at, Length: 10000, dtype: int64

# %%
from datetime import datetime

# %%
j=0
for i in df['created_at']:
    df['created_at'][j]=datetime.fromtimestamp(i)
    j=j+1
# Out:
# <ipython-input-6-b03988a90601>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['created_at'][j]=datetime.fromtimestamp(i)

# %%
df['created_at']
# Out:
# 0       2020-08-10 16:15:17
# 1       2020-08-11 11:45:22
# 2       2020-08-11 12:15:17
# 3       2020-08-12 16:15:17
# 4       2020-08-13 12:15:17
#                ...
# 9995    2020-09-25 21:28:58
# 9996    2020-09-25 21:28:59
# 9997    2020-09-25 21:28:59
# 9998    2020-09-25 21:28:59
# 9999    2020-08-14 14:45:18
# Name: created_at, Length: 10000, dtype: object

# %%
j=0
for i in df['sf_created_at']:
    df['sf_created_at'][j]=datetime.fromtimestamp(i)
    j=j+1
# Out:
# <ipython-input-8-5ac797317f16>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sf_created_at'][j]=datetime.fromtimestamp(i)

# %%
j=0
for i in df['sf_last_modified_at']:
    df['sf_last_modified_at'][j]=datetime.fromtimestamp(i)
    j=j+1
# Out:
# <ipython-input-9-15b6c8422dbd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sf_last_modified_at'][j]=datetime.fromtimestamp(i)

# %%
df.head()
# Out:
#                                          fields_data  sf_last_modified_at  \
# 0  {"AnnualRevenue": "", "City": "", "Company": "...  2020-08-10 15:43:29
# 1  {"AnnualRevenue": "", "City": "", "Company": "...  2020-08-11 11:43:53
# 2  {"AnnualRevenue": "", "City": "", "Company": "...  2020-08-11 11:53:26
# 3  {"AnnualRevenue": "", "City": "", "Company": "...  2020-08-12 16:11:32
# 4  {"AnnualRevenue": "", "City": "", "Company": "...  2020-08-13 11:41:50
#
#          sf_created_at    website_text           created_at  \
# 0  2020-08-10 15:27:36     offerup.com  2020-08-10 16:15:17
# 1  2020-08-11 11:37:17     offerup.com  2020-08-11 11:45:22
# 2  2020-08-11 11:33:52  u-clermont1.fr  2020-08-11 12:15:17
# 3  2020-08-12 16:02:46       metso.com  2020-08-12 16:15:17
# 4  2020-08-13 11:23:34      oracle.com  2020-08-13 12:15:17
#
#                zolo_lead_id sf_lead_company_website    sf_lead_company_name  \
# 0  5db811f786a45530631d9755             offerup.com                 Offerup
# ...

# %%
df['sf_last_modified_at']=pd.to_datetime(df['sf_last_modified_at'])   #conversion of obj to datetime dtype 
df['sf_created_at']=pd.to_datetime(df['sf_created_at'])
df['created_at']=pd.to_datetime(df['created_at'])
# Out:
# 0      2020-08-10 15:27:36
# 1      2020-08-11 11:37:17
# 2      2020-08-11 11:33:52
# 3      2020-08-12 16:02:46
# 4      2020-08-13 11:23:34
#                ...
# 9995   2020-03-11 20:11:31
# 9996   2020-05-21 01:06:16
# 9997   2020-06-09 20:58:27
# 9998   2020-04-03 19:57:15
# 9999   2020-08-14 13:53:17
# Name: created_at, Length: 10000, dtype: datetime64[ns]

# %%
df['sf_created_at'].dtype   # specific datatype   ----- datetime is a gen dtype maps to specific dtype
# Out:
# dtype('<M8[ns]')

# %%
df['created_at'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['sf_last_modified_at'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.isnull().sum()   #no of empty values
# Out:
# fields_data                   0
# sf_last_modified_at           0
# sf_created_at                 0
# website_text               1983
# created_at                    0
# zolo_lead_id               7022
# sf_lead_company_website    1982
# sf_lead_company_name          0
# sf_lead_id                    0
# sf_lead_name                  0
# sf_lead_email              3599
# id                            0
# user_account_domain           0
# dtype: int64

# %%
df['sf_lead_id'].count()   #no of sf_lead_id's
# Out:
# 10000

# %%
df['sf_lead_id'].nunique() #unique sf_lead_id's
# Out:
# 9557

# %%
df['sf_lead_name'].nunique()    ## few people have more than one sf_lead_id
# Out:
# 8761

# %%
df['id'].nunique()
# Out:
# 9966

# %%
df['id'].nunique()- df['sf_lead_name'].nunique()    ## 1205 people have more than one id
# Out:
# 1205

# %%
df['sf_lead_email'].unique()
# Out:
# array(['ignacio.izquierdo@offerup.com', 'prasad.ravilla@offerup.com',
#        'pierre.raynaud@u-clermont1.fr', ..., 'biju.thomas@msci.com',
#        'bennettwyche@gmail.com', 'ushakiranboppana@gmail.com'],
#       dtype=object)

# %%
df['sf_lead_email'].nunique()
# Out:
# 5722

# %%
df['id'].nunique()-df['sf_lead_email'].nunique()    ## 4244 ids have more than one sf_lead_email
# Out:
# 4244

# %%
duplicate = df[df.duplicated(keep='first')]   #finds   duplicate rows

# %%
duplicate.count()     # counts duplicate rows
# Out:
# fields_data                34
# sf_last_modified_at        34
# sf_created_at              34
# website_text               33
# created_at                 34
# zolo_lead_id               33
# sf_lead_company_website    33
# sf_lead_company_name       34
# sf_lead_id                 34
# sf_lead_name               34
# sf_lead_email              34
# id                         34
# user_account_domain        34
# dtype: int64

# %%
df[df.duplicated('id')]
# Out:
#                                             fields_data  sf_last_modified_at  \
# 517   {"AnnualRevenue": "", "City": "", "Company": "...  2020-08-14 14:11:54
# 518   {"AnnualRevenue": "", "City": "", "Company": "...  2020-08-14 14:11:54
# 1640  {"AnnualRevenue": "", "City": "", "Company": "...  2020-08-14 14:11:54
# 1704  {"AnnualRevenue": "", "City": "", "Company": "...  2020-08-14 14:11:54
# 2030  {"Additional_Lead_Information__c": "trying to ...  2020-08-06 18:47:50
# 2530  {"AnnualRevenue": "", "City": "", "Company": "...  2020-08-14 14:11:54
# 2785  {"AnnualRevenue": "", "City": "", "Company": "...  2020-08-14 14:11:54
# 2786  {"AnnualRevenue": "", "City": "", "Company": "...  2020-08-14 14:11:54
# 2794  {"AnnualRevenue": "", "City": "", "Company": "...  2020-08-14 14:11:54
# 2826  {"AnnualRevenue": "", "City": "", "Company": "...  2020-08-14 14:11:54
# 3202  {"AnnualRevenue": "", "City": "", "Company": "...  2020-08-14 14:11:54
# ...

# %%
user_account_domain=df.groupby(df['user_account_domain']).count()

# %%
user_account_domain
# Out:
#                                fields_data  sf_last_modified_at  \
# user_account_domain
# cloudpathfinderconsulting.com         2799                 2799
# fielo.com                             2048                 2048
# hope.com                               349                  349
# logo.com                               828                  828
# mailinator.com                          41                   41
# paradox.ai                            1258                 1258
# placetechnology.com                   2621                 2621
# strategisminc.com                       56                   56
#
#                                sf_created_at  website_text  created_at  \
# user_account_domain
# cloudpathfinderconsulting.com           2799          2663        2799
# fielo.com                               2048          1629        2048
# hope.com                                 349           346         349
# ...

# %%
user_account_domain.max()
# Out:
# fields_data                2799
# sf_last_modified_at        2799
# sf_created_at              2799
# website_text               2663
# created_at                 2799
# zolo_lead_id                986
# sf_lead_company_website    2663
# sf_lead_company_name       2799
# sf_lead_id                 2799
# sf_lead_name               2799
# sf_lead_email              2596
# id                         2799
# dtype: int64

# %%
df.columns
# Out:
# Index(['fields_data', 'sf_last_modified_at', 'sf_created_at', 'website_text',
#        'created_at', 'zolo_lead_id', 'sf_lead_company_website',
#        'sf_lead_company_name', 'sf_lead_id', 'sf_lead_name', 'sf_lead_email',
#        'id', 'user_account_domain'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   fields_data              10000 non-null  object
#  1   sf_last_modified_at      10000 non-null  datetime64[ns]
#  2   sf_created_at            10000 non-null  datetime64[ns]
#  3   website_text             8017 non-null   object
#  4   created_at               10000 non-null  datetime64[ns]
#  5   zolo_lead_id             2978 non-null   object
#  6   sf_lead_company_website  8018 non-null   object
#  7   sf_lead_company_name     10000 non-null  object
#  8   sf_lead_id               10000 non-null  object
#  9   sf_lead_name             10000 non-null  object
#  10  sf_lead_email            6401 non-null   object
#  11  id                       10000 non-null  int64
#  12  user_account_domain      10000 non-null  object
# ...

# %%
sns.pairplot(df)

# %% [raw]
# WORKING ON field_data COLUMN

# %%
df['fields_data'].dtypes
# Out:
# dtype('O')

# %%
df['fields_data'].nunique()
# Out:
# 9753

# %%
len(df['fields_data'])
# Out:
# 10000

# %%
len(df['fields_data'])-df['fields_data'].nunique()    ## 247 fields in df['fields_data'] is duplicate
# Out:
# 247

# %%
import json

# %%
Fields_data =pd.DataFrame(df['fields_data'])

# %%
Fields_data
# Out:
#                                             fields_data
# 0     {"AnnualRevenue": "", "City": "", "Company": "...
# 1     {"AnnualRevenue": "", "City": "", "Company": "...
# 2     {"AnnualRevenue": "", "City": "", "Company": "...
# 3     {"AnnualRevenue": "", "City": "", "Company": "...
# 4     {"AnnualRevenue": "", "City": "", "Company": "...
# ...                                                 ...
# 9995  {"AnnualRevenue": "", "City": "", "Company": "...
# 9996  {"AnnualRevenue": "", "City": "", "Company": "...
# 9997  {"AnnualRevenue": "", "City": "", "Company": "...
# 9998  {"AnnualRevenue": "", "City": "", "Company": "...
# 9999  {"AnnualRevenue": "", "City": "", "Company": "...
#
# [10000 rows x 1 columns]

# %%
Fields_data['fields_data'][1000]    ## all these keys would be the column names of a new dataframe
# Out:
# '{"AnnualRevenue": "", "City": "Bangalore", "Company": "Amazon", "ConvertedAccountId": "", "ConvertedContactId": "", "ConvertedDate": "", "ConvertedOpportunityId": "", "Country": "India", "CreatedById": "0052v00000f2BV6AAM", "CreatedDate": "2020-06-24T09:25:12.000Z", "CurrentGenerators__c": "", "Description": "", "Email": "ssaurabh@amazon.com", "EmailBouncedDate": "", "EmailBouncedReason": "", "Fax": "ssaurabh@amazon.com", "FirstName": "Sumit", "Id": "00Q2v00001gIRQDEA4", "Industry": "", "IsConverted": "false", "IsDeleted": "false", "IsUnreadByOwner": "false", "LastActivityDate": "", "LastModifiedById": "0052v00000f2BV6AAM", "LastModifiedDate": "2020-06-24T09:30:20.000Z", "LastName": "Saurabh", "LeadSource": "", "MasterRecordId": "", "MobilePhone": "", "Name": "Sumit Saurabh", "NumberOfEmployees": "", "NumberofLocations__c": "", "OwnerId": "0052v00000f2BV6AAM", "Phone": "", "PostalCode": "", "Primary__c": "", "ProductInterest__c": "", "Rating": "", "SICCode__c": "", "Salutation": "",
# ...

# %%
x=[]                                            ## to convert the Feild_data into a list
for i in Fields_data['fields_data']:
    x.append(json.loads(i))

# %%
df_feilds_data= pd.DataFrame(x)                 ## converting to a dataframe named df_feilds_data with all keys as columns and values as rows

# %%
len(df_feilds_data.columns)
# Out:
# 321

# %%
df_feilds_data.nunique()     ##unique values of each column
# Out:
# AnnualRevenue                           174
# City                                   1268
# Company                                6351
# ConvertedAccountId                      451
# ConvertedContactId                      496
#                                        ...
# What_s_the_project_about__c              18
# When_should_be_made_the_decision__c       1
# Which_Salesforce_license__c               1
# Which_version_of_the_product__c           3
# job_type__c                              13
# Length: 321, dtype: int64

# %%
null_val= df_feilds_data.isnull().sum()/len(df_feilds_data)                 ## finding the null values %age

# %%
null_val
# Out:
# AnnualRevenue                          0.0056
# City                                   0.0000
# Company                                0.0000
# ConvertedAccountId                     0.0000
# ConvertedContactId                     0.0000
#                                         ...
# What_s_the_project_about__c            0.7952
# When_should_be_made_the_decision__c    0.7952
# Which_Salesforce_license__c            0.7952
# Which_version_of_the_product__c        0.7952
# job_type__c                            0.7952
# Length: 321, dtype: float64

# %%
print(lambda x: null_val[x]==0.000,null_val)
# Out:
# <function <lambda> at 0x000001B92DD2F430> AnnualRevenue                          0.0056
# City                                   0.0000
# Company                                0.0000
# ConvertedAccountId                     0.0000
# ConvertedContactId                     0.0000
#                                         ...
# What_s_the_project_about__c            0.7952
# When_should_be_made_the_decision__c    0.7952
# Which_Salesforce_license__c            0.7952
# Which_version_of_the_product__c        0.7952
# job_type__c                            0.7952
# Length: 321, dtype: float64

# %% [markdown]
# DATA CLEANING

# %%
df_feilds_data=df_feilds_data.dropna(axis=1,how='all')    ##removing data with all null values

# %%
df_feilds_data.head()
# Out:
#   AnnualRevenue City                 Company ConvertedAccountId  \
# 0                                    Offerup
# 1                                    Offerup
# 2                     University Of Auvergne
# 3                                      Metso
# 4                                     Oracle
#
#   ConvertedContactId ConvertedDate ConvertedOpportunityId Country  \
# 0
# 1
# 2
# 3
# 4
#
#           CreatedById               CreatedDate  ... Target_Industries__c  \
# 0  0052v00000dQKDFAA4  2020-08-10T09:57:36.000Z  ...                  NaN
# 1  0052v00000dQKDFAA4  2020-08-11T06:07:17.000Z  ...                  NaN
# 2  0052v00000dQKDFAA4  2020-08-11T06:03:52.000Z  ...                  NaN
# 3  0052v00000dQKDFAA4  2020-08-12T10:32:46.000Z  ...                  NaN
# 4  0052v00000dQKDFAA4  2020-08-13T05:53:34.000Z  ...                  NaN
#
#   Timeframe__c Type_Of_Loyalty_Program__c Webinar__c  \
# 0          NaN                        NaN        NaN
# ...
